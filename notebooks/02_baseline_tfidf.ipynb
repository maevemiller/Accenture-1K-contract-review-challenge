# %% [markdown]
# # 02 — TF-IDF / Keyword Baseline
#
# Baseline multi-label classifier for the 10 selected clause categories, to give the fine-tuned DistilRoBERTa model (notebook 03) something concrete to beat. Per-category precision/recall/F1.
