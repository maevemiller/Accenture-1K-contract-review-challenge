# %% [markdown]
# # 03 — DistilRoBERTa Fine-Tuning
#
# Fine-tune DistilRoBERTa for multi-label classification across the 10 selected clause categories. Class-imbalance mitigation, per-category evaluation, and error analysis (per September/October milestones).
