# %% [markdown]
# # 04 — Risk Scoring
#
# Rule-based risk-scoring layer (Low/Medium/High) built on top of detected clauses, calibrated and validated against advisor-ranked contract samples via Spearman correlation (November milestone).
